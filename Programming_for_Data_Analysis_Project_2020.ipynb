# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Preliminaries" data-toc-modified-id="Preliminaries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preliminaries</a></span></li><li><span><a href="#Real-World-Phenomena" data-toc-modified-id="Real-World-Phenomena-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Real World Phenomena</a></span></li><li><span><a href="#Variables" data-toc-modified-id="Variables-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Variables</a></span><ul class="toc-item"><li><span><a href="#Average-Hours-Spent-in-Preparation-for-a-Job-Interview" data-toc-modified-id="Average-Hours-Spent-in-Preparation-for-a-Job-Interview-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Average Hours Spent in Preparation for a Job Interview</a></span></li><li><span><a href="#Level-of-Qualifications" data-toc-modified-id="Level-of-Qualifications-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Level of Qualifications</a></span></li><li><span><a href="#Level-of-Relevant-Job-Experience" data-toc-modified-id="Level-of-Relevant-Job-Experience-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Level of Relevant Job Experience</a></span></li><li><span><a href="#First-Impressions" data-toc-modified-id="First-Impressions-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>First Impressions</a></span><ul class="toc-item"><li><span><a href="#Eye-Contact" data-toc-modified-id="Eye-Contact-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Eye Contact</a></span></li><li><span><a href="#The-Handshake" data-toc-modified-id="The-Handshake-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>The Handshake</a></span></li><li><span><a href="#The-Smile" data-toc-modified-id="The-Smile-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>The Smile</a></span></li><li><span><a href="#Posture" data-toc-modified-id="Posture-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Posture</a></span></li><li><span><a href="#Small-Talk" data-toc-modified-id="Small-Talk-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Small Talk</a></span></li></ul></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# ![GMIT_Logo.png](attachment:GMIT_Logo.png)
#
#  **Programming for Data Analysis Assignment 2020**
#
#
#  **Author:**  Richard Deegan
#
#
#  **Lecturer:** Brian McGinley
#
#
#  **Student ID:** G00387896@gmit.ie

# %% [markdown]
# # Problem Statement
#
# For this project you must create a data set by simulating a real-world phenomenon of
# your choosing. You may pick any phenomenon you wish – you might pick one that is
# of interest to you in your personal or professional life. Then, rather than collect data
# related to the phenomenon, you should model and synthesise such data using Python.
# We suggest you use the numpy.random package for this purpose.
# Specifically, in this project you should:
#
#
# • Choose a real-world phenomenon that can be measured and for which you could collect at least one-hundred data points across at least four different variables.
#
#
# • Investigate the types of variables involved, their likely distributions, and their
# relationships with each other.
#
#
# • Synthesise/simulate a data set as closely matching their properties as possible.
#
#
# • Detail your research and implement the simulation in a Jupyter notebook – the
# data set itself can simply be displayed in an output cell within the notebook.
#
#
# Note that this project is about simulation – you must synthesise a data set. Some
# students may already have some real-world data sets in their own files. It is okay to
# base your synthesised data set on these should you wish (please reference it if you do),
# but the main task in this project is to create a synthesised data set. The next section
# gives an example project idea

# %% [markdown]
# # Preliminaries
#
# In order to effectively answer the Problem Statement various relevant libraries must be imported. For this we will import Numpy as it contains essential libraries namely the numpy.random library. Matplotlib.plyplot and Seaborn libraries will be utilised to assist in the visualisation of numbers to user friendly graphs.

# %%
# Import the the necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from faker import Faker

# %% [markdown]
# The magic inline command will be utilised in order to ensure the correct display of the plots within the Jupyter Notebook. This will allow the plots to be rendered inline within the Notebook [1].

# %%
# Magic command used to visualise plots in Jupyter
# %matplotlib inline

# %%
# control Seaborn aesthetics
# use darkplot plot style for contrast
sns.set_style("darkgrid")
# set the default colour palette
sns.set_palette("colorblind")
# set the size of the seaborn figures
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# Set the seed for Numpy Random
np.random.seed(1212)

# %% [markdown]
# # Real World Phenomena
#
# The real world phenomena that I have chosen to simulate and synthesize for this project is **"factors affecting the success of applicants for a job interview"**.
#
# **Variables Identified**
#
# - Average hours spent in preparation
# - Qualifications
# - Level of relevant job experience
# - Number of days absent
#
# Throughout this notebook I will be disscussing each of the variables listed above by simulating data sets. These data sets will be analysed and synthesized into diagrams for further analysis and discussion. I will create a dataframe in order to help visualise the data in a more user friendly way. Discussion will be focused on the relationships among the variables, and I will select and try to justify the most suitable distribution and their relationship. When choosing the most appropriate distribution for each variable I will have to take into account the certain aspects such as is it discrete or continuous. For instance, a continuous distribution has a range of values that are infinite, and therefore uncountable. For example, time is infinite, you could count from 0 seconds to a infinity and never stop counting. On the other hand a discrete distribution with finite support can only have a finite number of possible realizations. For example, the distribution associated with a coin toss experiment is discrete with finite support as you can only observe one of two.
#
#
#
# Literally hundreds of probability distributions have been defined mathematically. Some are used with such regularity that, like the normal and lognormal distributions, they have been given their own names. Many real-world random variables do, in fact, follow one of these distributions. Others don't, but even those can typically be closely approximated by named distributions.
#
# Uncertainty analysis often requires selecting a probability distribution for a random variable. Various methods have been proposed to assist the selection of probability distributions. Figure 35 provides a flow chart derived from Aswath [4]:
#
#
# ![Distribution_Curve.png](attachment:Distribution_Curve.png)

# %% [markdown]
# # Variables
#
# Section 4 will begin the construction of the variables chosen to anaylse the performance of applicants during a job interview.

# %% [markdown]
# ## Average Hours Spent in Preparation for a Job Interview

# %% [markdown]
# According to the Global Career Hub and the Association of International Certified Accountants, about 60% of persons spend four hours or less preparing for a job interview. About 28% spend between five and nine hours preparing for a job interview. Only 12% spend ten hours or more preparing for a job interview. This data was complied from 1,500 survey answers [2].  Its interesting that its suggested a minimum of ten hours is required to prepare for an interview, yet by their own research only 12% of persons are willing to put in such effort. This answer correlates exactly with the Google search "how many hours to spend in preparation for interview"
#
# ![Google%20Search.png](attachment:Google%20Search.png)
#
# Although this is by no means a definitive answer it does provide a good approximation of the preparation required that is generally recommended.

# %%
# Use Faker to faek names
fake = Faker()
fake.name()

print(fake.name())

# Create an empty list
Fake_Name_List = []
# Create a for loop 1500 times
for i in range(1500):
    # Append fake naems to list 
    Fake_Name_List.append(fake.name())
    # Print names
    print(fake.name())
# Out:
# Dr. Michael Coleman PhD
# Ivan Mcdowell
# Troy Lee
# Caitlyn Castillo
# Tracy Schroeder
# Shawn Martinez
# John Carroll
# Michelle Harrington
# Amber Williams
# Andrew Garcia
# Hayden Compton
# Mr. David Yu
# Mark Parks
# Jessica Melendez
# Isaiah Rivera
# Scott Anderson
# Eric Fox
# Stephanie Goodman
# Jennifer Beltran
# Christopher Gonzales
# Dr. Heather Weaver
# Alicia Foster
# Sean Steele
# Debra Cervantes
# Kimberly Wade
# Thomas Johnson
# Sarah Barr
# Justin Simpson
# Tracie Brown
# Angela Doyle
# Kimberly Holmes
# Ann Jacobs
# Lucas Vargas
# Megan Austin
# Chad Soto
# Paige Murphy
# Sherri Henry
# Briana Cox
# Kimberly Martin
# Justin Moon
# Nicole Jordan
# Nathaniel Richards
# Michael Boyd
# Jessica Harper
# Angela Ball
# Katie Hunter
# Betty Hernandez
# Dennis Eaton
# Russell Clayton
# Nicholas Smith
# Paul Brown
# Tanya Montes
# Ronald Smith
# Jason Cohen
# Mrs. Sarah Smith
# Veronica Monroe
# Corey Richardson
# Stacey Crawford
# Gary Powers
# Jeffrey Kelley
# Mark Newman
# Cynthia Salinas
# Gregory Ellis
# Mark Hayes
# Andrew Bond
# Robin Perkins
# Brandon Washington
# Glenn Hubbard
# Nicholas Mills
# Mrs. Jessica Salas DVM
# Mark Davis
# Joy Jones
# Patrick Pearson
# Chad Garcia
# Virginia Schwartz
# Melissa Johnston
# Cole Scott
# John Olson
# Jason Reed
# Sara Brown
# William Wallace
# Cynthia Garcia
# Daniel Williams
# Natalie Kim
# Greg Beltran
# Dana Mason
# David Kane
# David Wu
# Tina Tyler
# Jonathan Tucker
# Lori Cooper
# Randy Rhodes
# Elizabeth Hernandez
# Mr. Samuel Mitchell
# James Hoffman
# Troy Hall
# David Walker
# Dennis Valdez
# Patricia Morris
# Patricia Johnson
# Amy Carr
# William Peterson
# Laura Preston
# Daisy Burgess
# Matthew Ryan
# Lauren Green
# Duane Erickson
# Carrie Jacobs
# Eric Morris
# Denise Carter
# Christopher Newton
# Melissa Allen
# Alexander Graham
# Paula Dodson
# Elizabeth Rodriguez
# Maria Garcia
# Taylor Wright
# Rachel Estes
# Jacob Wright
# Cindy Allen
# Terry Thompson
# Ronald Jacobs MD
# Kevin Mcdonald
# Anthony Medina
# Jonathan Oliver
# Marissa Hart
# Gina Schmidt
# Zachary Graham DVM
# Melissa Little
# Amy Dixon
# Michele Hill
# Susan Johnson
# Sylvia Grant
# Patricia Smith
# Robert Turner
# Michael Hubbard
# John Trujillo
# Elizabeth Mccarthy
# Bryan Harrison
# Ryan Delgado
# Michael Barnett
# Tyler Ochoa
# Tony Davis
# Megan Lee
# Scott Ross
# Sergio Martin
# Patrick Lucas
# Briana Guzman
# Lisa Martinez
# Cynthia Barnett
# Angel Ortiz
# Adrian Carey
# Micheal Maxwell
# Patrick Kemp
# Daniel Collins
# Olivia Dominguez
# Jeffrey Barrett
# Lindsey Williams
# Crystal Lawson
# Michael Howell
# Dennis Lang
# Courtney Scott
# Chloe Freeman
# Jennifer Carter
# Chris Proctor
# James Mejia
# James Jimenez
# Robert Rogers
# Douglas Smith
# Kim Jackson
# Diane Kramer
# Chad Gordon
# Timothy Walton
# Carol Campbell
# Greg Bernard
# Kristen Perry
# Christina Dickerson
# Dana Howard
# Jacob Martinez
# Tristan Allen
# Kimberly Anderson
# James Anderson
# Jeffery Ewing
# Charles Cabrera
# Phillip Stout
# Stephanie Oconnor
# Patrick Rivera
# Francisco Hartman
# Tim Frost
# Scott Parks
# Natalie Jones
# Amanda Smith
# Denise Nguyen
# Miguel Morgan
# Sarah Huff
# Ronald Gonzalez MD
# Stephen Mcdonald
# Rachel Casey
# Melissa Price
# Kaitlin Moore
# Patrick Silva
# Phillip Cantu
# Kevin Meyers
# Maria Chandler
# Sean Carter
# Sheri Harris
# Stephanie Green
# Jackson Parker
# Keith Chang
# Robert Bradley DDS
# Erica Brown
# Mr. Todd Moore
# Mark Johnson
# Rita Conley
# Melissa Brown
# Michele Fisher
# Melissa Frye
# Daniel Jimenez
# Denise Parker
# Janet Simpson
# Heidi Scott
# Bobby Stevens
# Darren Morris
# Eric Harris
# Ellen Scott
# Jacqueline Grimes
# Wendy Jones
# Courtney Simmons
# Lisa Rose
# Mr. Raymond Frazier
# Sheila Carter
# Todd Knapp
# April Thompson
# David Washington
# Jeremiah Avila
# Jesse Garcia
# Heather Cannon
# Amanda Mccann
# Patrick Boyd
# Timothy Burke
# Jennifer Boyd
# Michael Frazier
# Mrs. Toni Palmer
# Ian Franklin
# Charles Davidson
# Michele Garcia
# Francis Banks
# Andrew Knapp
# Kristina Leon
# Richard Roberson
# Ronald Murray
# Candice Stevenson
# Heidi Boone
# Jennifer Lyons
# Matthew Price
# Marcus Fowler
# Diana Murphy
# Morgan Garcia
# Beth Pierce
# Donald Hernandez
# Christine Watson
# Judith Barnes
# Debra Harmon
# Connie Brown
# Michelle Harris
# Stephanie Cortez
# Matthew Murray
# Shawn Fleming
# Amanda Diaz
# Alexandra Johns
# Susan Zimmerman
# Bruce Cox
# Kim Adkins
# Teresa Young
# Kimberly Wiley
# Jeffery Butler
# David Miller
# Scott Trujillo
# Lisa Hanna
# Autumn Anderson
# Jennifer Fuller
# Kelly Simpson
# Steven Johnson
# Bill Cain
# Karen Munoz
# Gary Bates II
# Brittany Robinson
# Victoria Ramirez
# Grace Rodriguez
# Vincent Vasquez
# Kevin Smith
# Krystal Carr
# Nicholas Ashley
# Kimberly Castro
# Sabrina Delgado
# Troy Duke
# Gary Boyd Jr.
# Angela David
# Samantha Martinez
# Ashley Coleman
# Tony Johnson
# Christina Esparza
# Vickie Welch
# Melanie Pena
# Kelly Waller
# Brian Wise
# John Landry
# Dr. Margaret Garcia
# Adam Parker
# Annette Rosales
# John Lewis
# Ryan Mckee
# Tina Collins
# Jonathon Hurley
# Jamie Pham
# Stacy Johnson
# Shannon Mitchell
# Emily Smith
# Justin Duncan
# Jose Heath
# Lynn Leonard
# Rebecca Figueroa
# Samuel Aguilar
# David Juarez
# Daniel Campbell
# Dawn Weiss
# Julie Guzman
# William Campbell
# Carlos Livingston
# Roger Yates
# Jennifer Anderson
# Holly Obrien
# Brandy Huff
# Barbara Ponce
# Thomas Sweeney
# Jessica Dean
# Nichole Smith
# Kevin Lee
# Paul Hurley
# Vincent Nicholson
# Penny Brown
# Ryan Nichols
# Alicia Lee
# James Gross
# George Williams
# Maurice Ward
# Lawrence Butler
# Amy Ward
# Kimberly Anderson
# Kim Williams
# Eric Wilson
# Joshua Edwards
# Benjamin Schmitt
# Sean Erickson
# Marvin Perry
# David Daniels
# Willie Brooks
# Shelia Brown
# Chelsea Mitchell
# Ashley Armstrong
# Samuel Greer
# John Estes
# Jaime Humphrey
# Sandy Frank
# Sarah Cox
# Ryan Taylor
# Dawn Ross
# Brittany Stevens
# James Harrington
# Jared Davis
# Terrence Walker
# Richard Miller
# Sherry Lam
# Michael Nichols
# John Cabrera
# John Stephens Jr.
# Deborah Newman
# William Arnold
# Teresa Rogers
# Jennifer Alvarez
# Jesus Bauer
# John Howard
# Whitney Burns
# Ian Graham
# Margaret Mendoza
# Michael Vaughan
# Kenneth Hoover
# Brian Watson
# Natasha Roberts DDS
# Robert Johnson
# Teresa Soto
# Anne Gallegos
# Daniel Sharp
# William Bowman
# Breanna Carroll
# Linda Harris
# Stephanie Silva
# Tammy Moore
# Caitlin Buckley
# Amber Anderson
# Ashley Mason
# Danny Taylor
# Jennifer Sanchez
# Carol Martinez
# Kimberly Mckinney
# Ashley Ferguson
# Eric Cox
# Mr. Henry Hill
# Dustin Anderson
# William Grant
# Mary Contreras
# Julia Tucker
# Terry Castaneda
# Lauren Hoover
# Natalie Mitchell
# Jessica Kelly
# Mark Morris
# April Gallegos
# Dawn Carney
# Alan Johnson
# Taylor Meyer
# Denise Mccullough
# Linda Farley
# Jane Jackson
# Grace Huang
# Melinda Burch
# David Barnes
# Thomas Willis
# Holly Luna
# Shelly Reid
# Jessica Boyle
# Joseph Banks
# Shannon Ryan
# Melissa Thomas
# Jessica Gutierrez
# Jose Poole
# Tonya Shea
# Chloe Ballard
# Zachary Potts
# Kevin Hodges
# Jonathan Mcdonald
# Jason Santiago
# Lori Brooks
# Paul Knapp
# Crystal Miller
# Jennifer Mejia
# Steven Krueger
# Kathryn Mcmahon
# Debbie Harrison
# Brett Lane
# Jennifer Cannon
# William Clark
# Marcus Miller
# Melissa Hernandez
# Amanda Vance
# Paul Macdonald
# Jennifer Jackson
# Anthony Ford
# Jonathan Lawrence
# Dwayne Ortiz
# Susan Medina
# Miss Betty Torres
# Brianna Wilkerson
# Theresa Walter
# Richard Lee
# Christopher Thompson
# Aaron Parker
# Anthony Cervantes
# Wayne Freeman
# Jeremy Hanson
# Andrew Roberts
# Jennifer Lopez
# Brandon Taylor
# James Mcdonald
# Brittney Walsh
# Nicholas Smith
# Brenda Thompson
# Mrs. Cassandra Gordon
# Shelby Silva
# William Watson
# Stephen Summers
# Pamela Franklin
# Jordan Rivera
# Crystal Bruce
# Kenneth Green
# Thomas Patel
# Jerome Love
# Joshua Bartlett
# Paul Gonzalez
# Gabrielle Stewart
# Kevin Lambert
# William Sexton
# Cory Mason
# Anthony Frank
# David Martin
# Michele Nelson
# Richard Anderson
# Marcus Wood
# Priscilla Rodgers
# Keith Hoover Jr.
# Casey Patel
# Amanda Monroe
# Alejandro Smith
# Christian Vasquez
# Rhonda Howard
# Jose Morrison
# Danny Pratt
# Madison Lang
# Vanessa Thomas
# Anne Hanna
# Nathan Thomas
# Justin Smith
# James Nelson
# Jennifer Davies
# Daniel Meyer
# Michael Warren
# Kelly English
# Jennifer Boyle
# Cindy Jones
# Holly Schmidt
# Meredith Buckley
# John Bell
# Margaret Compton
# Austin Santos
# Roy Boyle
# Victor Stevens
# Jared Richardson
# Alicia Pittman
# Victor Brock
# Peter Tyler
# Judy Mcdonald
# Paul Warren
# David Rose
# Robert Hardin
# Jordan Parrish
# Connie Brown
# Philip Simmons
# Lisa Oliver
# Matthew Lopez
# Amanda Barber
# Alexa Anderson
# Alan Fox
# Tom Roberts
# Christopher Johnson
# Jeffrey Vaughn Jr.
# David Simpson
# Sarah Jenkins
# Joseph Hood
# Donald Garza
# David Rice
# Jennifer Ross
# Stacey Yoder
# Joseph Long
# Isaac Pugh
# Stephen Mcintyre
# Breanna Barry
# Andrew Yoder
# Chase Larson
# Julia Brown
# Deborah Brown
# Kyle Wells
# Angela Lopez
# Katherine Edwards
# Amy Anderson
# Michelle Orr
# Andrew Williams
# John Mcmahon
# Andrew Rush
# Heather Newman
# Ryan Butler
# James Martin
# Jamie Green
# Erica Eaton
# Lisa Newton
# Mrs. Stephanie Brown MD
# Taylor Stafford
# Lisa Dominguez
# Joshua Acosta
# Samantha Allen
# Mike Ramos
# Dominic Sullivan
# Michelle Blake
# Claudia Sanchez
# Bryan Jensen
# George Sanders
# Andrew Curtis
# Joshua Perry
# Michael Whitehead
# Christopher Ramirez
# Stephanie Wright
# Stephanie Moody
# Katherine Figueroa
# Kimberly Herring
# Edward Nielsen
# Angela Richardson
# Roberto Carney
# Vanessa Johnson
# James Sparks
# Rachel Thomas
# Samantha Ayala
# Cory Wilkinson
# Julie Hunt
# Christina Shepard
# Stanley Ayers
# Sandra Fernandez
# Kyle Hardy
# Brian Lyons
# Sergio Harmon
# Steven Burch
# Dana Werner
# Alicia Blake
# Kylie Evans
# Chad Herrera
# Autumn Lynch
# Antonio Harper
# Amanda Holder
# Sheila Thompson DDS
# Erik Long
# John Sweeney
# Deborah Harris
# Todd Johnson
# John Johnston
# Erica Thomas
# Todd Reed
# Kenneth Roberts
# Donald Marquez
# Daniel Nguyen
# James Hall
# Tara White
# Steven Daniels
# Nicholas Parks
# Jacqueline Owen
# Sandy Smith
# Amber Fitzgerald
# Sandra Nunez
# Aaron Romero
# Tyler Woods
# Madison Rodriguez
# Rodney Brewer
# Bonnie Cruz
# Joseph Smith
# Linda Smith
# Chad Solis
# Jeffrey Park
# Charles Owens
# Tracie Ramirez
# Helen Key
# Benjamin Livingston
# Sean Smith
# Morgan Vaughn
# Terry Castaneda
# Sean Garcia
# Sydney Fry
# Kimberly Nguyen
# Crystal Kline
# Kathy Garcia
# Madeline Clark
# Melinda Ramirez
# Edward Wilson
# Matthew Hodge
# Dennis Wright
# Preston Diaz
# Joshua Krause
# Elizabeth Day
# Benjamin Morris
# Denise Price
# Heather Smith
# William Anderson
# Mrs. Abigail Cain
# Julia Rollins
# Abigail Villarreal
# Jeremy Morris
# Cory Thomas
# Nathaniel Pacheco
# Jonathan Wells
# Sarah Taylor
# Shannon Conner
# Christopher Turner
# Troy Morgan
# Jessica Booker
# Michelle Ruiz
# Danielle Gilbert
# Vincent Adams
# William Barnes
# Dawn Ray DVM
# Kiara Elliott
# Luis Peterson
# Joseph Hutchinson
# Jennifer Hill
# Angelica Hunter
# Steven Perry
# Gerald Escobar
# Charles Thomas
# James Moore
# Wendy Horne
# Michael Fleming
# Jamie Wheeler
# Christopher Smith
# April Lamb
# Brenda Jimenez
# Christina Cunningham
# Brandon Dawson
# Matthew Weber
# Nicholas Smith
# Angela Cooper
# Brian Allen
# Joseph Salinas
# Michael Mccormick
# Matthew Smith
# Anna Davis
# Lynn Bright
# Candice Aguilar
# Kenneth Raymond
# Erica Dennis MD
# Robert Jones
# John Suarez
# Jacqueline Cabrera
# Zachary Allen
# Jane Golden
# Stephanie Jones
# Patricia Fleming
# Paul Rios
# Ebony Whitehead
# Madison Payne
# Zachary Rubio
# Sergio Martin
# Miranda Navarro
# Michael Hayes
# Ashley Schmidt
# Karen Davis
# Karen Anderson
# Randall Weaver
# Matthew Zuniga
# Susan Nichols
# Jillian Chandler
# Kathryn Smith
# Christian Smith
# Theresa Weaver
# Ashley Cooper
# Terry Hill
# Cheryl Cobb
# Jason Carter
# Brenda Barton
# Stephanie Delacruz
# Melissa King
# Jeremy Smith
# William Barton
# David Johnson
# Robert Flynn
# Robert Meza
# Timothy Cooper
# Jessica Hall
# Ashley Ramirez
# Amy Nichols
# Angela Clark
# Jennifer Bailey
# Casey Cooper
# Molly Joyce
# Michelle Morgan
# Paul Sparks
# Jeffrey Pierce PhD
# Jessica Hurst
# Patricia Hughes
# Alexa Brady
# William Warren
# Vincent Arellano
# Deanna Walker
# Crystal Taylor
# Amy Long
# Garrett Lam
# Amy Burns
# Nicholas Garcia
# Jessica Jenkins
# Brian Douglas
# Michelle Evans
# Mrs. Sara Elliott
# Paul Brooks
# Kevin Campbell
# Katherine Graham
# Devin Grant
# Samantha Jarvis
# Jesse Martin
# Nicholas Williams
# Rita Sims
# Caitlin Scott
# Joe Washington
# Natasha Pierce
# Stacy Garza
# Robert Peterson
# Angela Livingston
# Steven Wang
# Jessica Ray
# Brittany Wood
# Jacqueline Obrien
# Traci Barron
# Janice Shaw
# Randy Richardson
# John Foster
# Katherine Reeves
# Lisa Dominguez
# Gregory Clark
# Tracy Rodriguez
# Lisa Aguilar
# Robert Stewart
# Steven Sampson
# Corey Barker
# Luke Nguyen
# Dale Vega
# Hannah Roy
# Regina Gordon
# Dana Williams
# Kelly Hernandez
# Carolyn Farley
# April Lester
# Julia Reid
# Emily Morris
# Darrell Hubbard
# Kevin Moore
# Angela Hayes
# Terry Reed
# Kevin Rogers
# Elizabeth Galvan
# Timothy Jacobs
# April Porter
# Brandon Hart
# Justin Green
# Wanda Davila PhD
# Ariel Bass
# Michael Snyder
# Morgan King
# Andrew Rogers
# Ryan Perez
# Luis Lee
# Stephen Wolfe
# Carrie Ross
# Kenneth Hansen
# Debra Duran
# Derek Perry
# Brandy Macias
# Holly Sutton
# Mikayla Bradley
# Michael Adams
# Alexis Harrison
# Anthony Phillips
# Allison Cook
# Tami Myers
# Tanya Burton
# Randy Martin
# Theresa Jordan
# John Benitez
# Frank Turner
# Mark Cline
# Lisa Richard
# William Smith
# Bryan Conrad
# Ryan Bates
# Michael Schultz
# Stephen Scott
# Veronica Bell
# Jeffrey Chapman
# Tyler Harrell
# David Smith
# Kristina Reid
# Virginia Allison
# Cassandra Collins
# Darin Perez
# Alexander Bell V
# Monica Johnson
# Mark Perkins
# Felicia Perkins
# Jordan Cook
# Elizabeth Powers
# Manuel Wright
# Brandon Rice
# Tiffany Nunez
# John Jimenez
# Cheryl Hardy
# Michelle Elliott
# Darin Colon
# Bradley Scott
# David Gross
# Timothy Gomez
# Richard Rivas
# Nancy Page
# Tyler Barrett
# Lydia Dominguez
# Charles Buchanan
# Sarah Lee
# Sandra Butler
# Brandon Rogers MD
# Chad Anderson
# Rhonda Mills
# Cassandra Barnes DVM
# Kelly Knight
# Lindsay Lee
# Erik Gates
# Ernest Rodriguez
# Jeffrey Benson
# Stephanie Nichols
# Geoffrey Mcdonald
# Christopher Anderson
# Mr. Travis Decker MD
# Elizabeth Hansen
# Haley Lopez
# Kyle Carrillo
# David Owens
# Jaime Jackson
# Loretta Pena
# Todd Price
# Kyle Kelley
# Linda Estrada DDS
# Andrea Juarez
# Wesley Hayes
# Anthony Nelson
# Whitney Cooper
# Christian Hall
# Joanna West
# Joseph Chambers
# Brendan Schmitt
# Michelle Ford
# Sheri Contreras
# Nathan Freeman
# Alexandria Johnston
# Claudia Mueller
# William Myers
# Margaret Brown
# Nathan Harris
# Rebecca Baxter
# Heather Richardson
# Daniel Hunt
# Jeremy Sosa
# Kenneth Parsons
# Todd Rose
# James Lawrence
# Max Bennett
# Daniel Hudson
# Alicia Camacho
# Andrew Obrien
# Amanda Robinson
# Steven Bailey
# Daniel Campbell
# Haley Harper
# Sarah Thomas
# Elizabeth Byrd
# Austin Pacheco
# Taylor Orr
# Shannon Fleming
# Bradley Anderson
# Jill Booth
# Katherine Kim
# Gary Ferguson
# Zachary Baker
# Joshua Nguyen
# Angel Gray
# Elizabeth Watts
# Kristine Gentry
# Tracey Russell
# Jeanne Rivera
# Nathan Dixon
# Donald Robbins
# Anna Rodriguez
# Sarah Hensley
# Kelly Day
# Kyle Cunningham
# Jorge Tapia
# Tonya Blair
# Angela Lopez
# Stephanie Guzman
# Jose Mcgee
# Katherine Baker
# Steven Taylor
# Mrs. Marissa Stevens MD
# Marie Ballard
# Felicia Miller
# Daniel Campos
# Edwin Johnson
# Laura Rivera
# Courtney Pratt
# Steven Carroll
# Mrs. Mary Schmidt
# Carlos Wood
# Renee Taylor
# Shawn Ali
# Andrew Yates
# Nicholas Ross
# Jared Sullivan
# Sharon Sanchez
# Jessica Barker
# Emily Holt
# Mark Higgins
# Chad Larson
# Daniel Baker
# Catherine Thomas
# Jesse Meyer
# Robert Johnston
# Barbara Herrera
# Tammy Martin
# David Bradley
# Leah Hall
# James Vasquez
# Becky Hawkins
# Sheila Pratt
# Jessica Wright
# Mark Hall
# Sarah Griffin
# Joseph Harris
# Zachary Morales
# Nancy Smith
# Cody Bond
# Joan George
# Brian Miller
# Brian Dalton
# Joshua Herman
# Stephanie Ponce
# Dana Moore
# Ashley Dean
# Jose Brown
# Melanie Woods
# Sean Perez
# Dennis Hall
# Mrs. Michelle Thomas
# Kelly Miranda
# Mrs. Mary Hart MD
# Teresa Murray
# Douglas Gray
# Courtney Williams
# Kenneth Martinez
# Sue Foley
# Andrew Huang
# William Hicks
# Vincent Macdonald
# Patrick Lozano
# Anne Diaz
# Debbie Garcia
# Stuart Mejia
# Todd Wong
# Amanda Martinez
# Michael Williamson
# Scott Rodriguez
# Michael Nunez
# Luis Hopkins
# Rose Morgan
# Sonya Richard
# Chris Mcdaniel
# Martin Lambert
# Douglas Holden
# Sarah Hill
# Rebecca Brown
# Cole Callahan
# Sandy Hardy
# Michael Weaver
# Thomas Johnson
# Joseph Curtis
# Kristen Dunn
# David Hamilton
# Kimberly Rhodes
# Joseph Boyer
# Angela Wells
# Nicholas Gomez
# Joseph Terrell
# Amanda Kerr
# Timothy Adams
# Paul Mays
# Christine Cooper
# Sean Estrada MD
# George Harris
# Catherine Jordan
# Kyle Nguyen
# Christopher Morris
# Gregory Sharp
# Nicole Davis
# Derrick White
# Jennifer Johnson
# Patricia Hughes
# Alan Weiss
# Mr. Daniel Murphy II
# Sarah Williamson
# Isabella Thomas
# Brett Hernandez
# John Simmons
# Sarah Oconnor
# Victoria Patel
# Maureen Odonnell
# Michele Richardson
# Scott Larson
# John Bean
# Jessica Sutton
# Ryan Cooper
# Gregory Chan
# Lawrence Howell
# Aaron Carson
# Joseph Carter
# Leslie Robinson
# Stephanie Miller
# Austin Simmons
# Paul Moreno
# Melvin Olsen
# Matthew Dixon
# Joe Walton DVM
# Jennifer Moore
# Pamela Larsen
# Brian Young
# Samantha Leon
# Lisa Cole MD
# Tammy Knight
# Robert Black
# Russell Lewis
# David Smith
# Jody Gregory
# Megan Wright
# Michael Foster
# Tony Hill
# Samuel Jones
# Daniel Esparza
# Olivia Reed
# Joseph Baker
# Savannah Ashley
# Lauren Lynn
# Jessica Norris
# Sharon Francis
# Michael Garcia DDS
# Deanna Burton
# Michael Reynolds
# Eric Guerrero
# Thomas Rubio
# Tony Harris
# Mike Smith
# Cassandra Atkinson
# Kenneth Bray MD
# Amy Green
# Lisa Gordon
# Robert Soto
# Michael Jenkins
# Jamie Gomez
# Tracey Bauer
# Christina Dennis
# Ana Thomas
# Sheri Stevens
# Pamela Walters
# Anthony Parks
# Colin Ortega
# James Huff
# Carmen Martinez
# Jim Ballard
# Gloria Johnson
# Joseph Franco
# Diana Hurley
# Christopher Jenkins
# Suzanne Jordan
# Kyle Garza PhD
# Amber Delgado
# Kenneth Jones
# Misty Anderson
# Kevin Benitez
# Paul Davis
# George Edwards
# Michelle Osborne
# Mitchell Fuller
# Erin Richardson
# James Howard
# Anthony Jones
# Richard Diaz
# John Morris
# Taylor Wall
# Scott Taylor
# Jonathan Gonzalez
# Ryan Carter
# Justin Hicks
# Shannon Hernandez
# Kimberly Alvarez
# Shannon Zamora
# Jason Thompson
# Amanda Rojas
# Heather Rogers
# Erik Kelly
# Sean Parsons
# Rhonda Ramsey
# Nicole Hall
# Alyssa Johnson
# Matthew Johnson
# Jesse Rhodes
# Geoffrey Mendoza
# David Walker
# Wanda Henson
# Tiffany Ortega
# Anthony James
# Lisa Reyes
# Scott Thomas
# Matthew Taylor
# Cynthia Villegas
# Kelsey Hill
# Autumn Moore
# Matthew Horton MD
# Karen Daugherty
# Thomas Garrison
# Zachary Parsons
# Christopher Mcclain
# Jill Thomas
# Chad Carpenter
# Kathryn Young
# Hayden Robinson
# William Melendez
# Mark Bishop
# Stefanie Bennett
# Jeffrey Coleman
# Thomas Winters
# Janice Miller
# Carmen Everett
# Tina Conley
# Jessica Ford
# Christopher Massey
# Anne Rogers
# Thomas Wilkins
# Angela Dominguez
# John Higgins
# Amanda Miller
# John Wiley
# Brenda Floyd
# Jesse Ward
# Robert Sanchez
# Robert Wright
# Paula Saunders
# Heidi Nolan
# Pamela James
# Mrs. Lauren Jackson DDS
# Sharon Elliott
# Mark Jones
# Kelly Stephens
# Mary Rosales DDS
# Wayne Martin
# Amber Martin
# Heather Graves
# Geoffrey Church
# Christopher Brown
# Amy Smith
# Angela Morgan
# David Robinson
# Tyler Hansen
# Arthur Bass
# Jane Stevenson
# Diana Moran
# Adrian Russell
# Tony Peters
# Christine Bell
# John Humphrey
# Christina Melendez
# Joseph Beard
# Deborah Howard
# Alisha Palmer
# Victor Wood
# Alexa Wallace
# Zachary Obrien
# Jennifer Compton
# Blake Elliott
# Tina Clark
# Kelly Davis
# Allison Leonard
# Carla Gonzales
# Marissa Adams
# Mark Wiley
# John Harrell
# Michael Stein MD
# Amanda Orozco
# Brian Mckee
# Alexander Blackwell
# Allison Green
# Anna Barber
# Samuel Price
# Lisa Cohen
# Christopher Kerr
# Jonathan Henderson
# Dylan Morgan
# Nancy Williamson
# Charles Berry
# Lauren Smith
# John Morales
# Kristi Gibson
# Terri Gonzalez
# Emily Hart MD
# James Young
# Angela Rojas
# Zachary Johnson
# Miss Briana Merritt
# Terry Lopez
# Daniel Booth
# Jenny Bates
# Connie Marshall
# Patrick Reyes
# Nicholas Gomez
# Amanda Guerra
# Amanda Smith
# Brian Chan
# Anthony Adams
# Christopher Mitchell
# Rachel Perez
# Alyssa Curtis
# Steven Lee
# Yvette Burke
# Christopher Thompson
# Jacob Davis
# Melissa Watkins
# Jacob Shepard
# Christine Cervantes
# Kim Massey
# Sara Guzman
# Derek Figueroa
# Anna Hendrix
# Chelsea Brown
# Megan Snyder
# Christopher Hill
# Shawn Garrison
# Hannah Robinson
# Heidi Thornton DVM
# Amber York
# Jamie Perry
# Tracy Cardenas
# Jessica Johnson
# Jesse Reeves
# Brenda Chapman
# Larry Dalton
# Kelly Martin
# David Peters
# Marcia Farrell
# Katelyn Jones
# Jose Cole
# Dylan Lee
# Douglas Morris
# Debbie Richardson
# Lindsey Kennedy
# Mark Johnson
# Jessica Moreno
# Erika Kelly
# Patrick Payne
# Keith Fitzgerald
# Kristen Evans
# Kylie Lewis
# Michael Baker
# Michael Travis
# Sarah Flores
# Robert Bond
# Mary Gomez
# Dustin Gonzalez
# Joshua Irwin
# Pamela Taylor
# Cynthia Smith
# Ashley Dominguez
# Christopher Hall
# Mr. Seth Harris DDS
# Michael Butler
# Dean Daniel
# Justin Brown
# Jill Davidson
# Matthew Hunt
# Richard Johnson
# Kenneth Scott
# Michael Benitez
# Alexis Mejia
# Rebecca Phillips
# Stacy Smith
# Stephen Morris
# Nancy White
# Charles Wright
# Raymond Craig
# Anna Roberts
# Marie Martin
# Desiree Baker
# Tammy Lewis
# David Bell
# Misty Kim
# Melissa Solis
# Jessica Johnson
# David Smith
# Robert Williams
# Patricia Black
# James Fitzpatrick
# Christopher Ware
# Dennis Myers
# Brandon Cortez
# Aaron Lamb
# Kristina Lopez
# Amanda Dickson
# Shelia Williams
# Shannon Long
# James Jackson
# Richard Fritz
# Michael Williams
# William Friedman
# Patricia Smith
# Olivia Sanchez
# Justin White
# Kaylee Lopez
# Nicole Bolton
# Brandon Simmons
# Kelly Dudley
# Kenneth Lewis
# William Barnes
# Brittney Mason
# Michelle Lawrence
# Anna Marquez
# Michael Moore
# Patricia Mcgee
# Brian Buchanan
# Maria Brooks
# Pam Johnson
# Keith Fields
# Brittany Mcgrath
# John Kelly
# John Thomas
# William Johnson
# Leslie Brown
# Anthony Garcia
# Alexander Rojas
# Samuel Bennett
# James Perez MD
# Matthew Moore
# Daniel Brewer
# Douglas Larsen
# Lisa Lewis
# William Morrison
# Lindsey Braun
# Brian Medina
# Sean Brown
# Kimberly Garrett
# Brett Dominguez
# Daniel Chan
# Brian Holmes
# Henry Glover
# Dominic Blake
# Daniel Cannon
# Crystal Branch
# Jessica Boyle
# Victoria Rodriguez
# Diana Crawford
# Rebekah Meyer
# Julia Martin
# Angela Richards
# Laura Anderson
# Paul Taylor
# Steven Monroe
# Sandra Morris
# Scott Fisher
# Margaret Howard
# Lance Monroe
# Mr. Christopher Palmer
# Cory Silva
# Peter Weaver
# Jill Torres
# Theresa Brown
# Justin Wilson
# Cody Bradford
# Crystal Miller
# Krista Carson
# Joyce Vasquez
# Kelly Reyes
# Sheri Lane
# Tracey Lopez
# Brooke Santiago
# Allen Davis
# Taylor Brown
# Robert Brooks
# Leslie Butler
# Ashley Brown
# Elizabeth Ray
# Dr. Monica Holloway
# Mark Shaw
# Kristin Holland
# Christina Contreras
# Rachel Colon
# Emily Ruiz
# Nicole Clark
# Caitlyn Williams
# Andrew Gibson
# Thomas Mcdaniel
# Heather Raymond
# Joseph Peterson
# Jessica Johnson
# Jeffery Parker
# Jordan Jimenez
# James Wang
# Mr. Brandon Ponce
# Tanya Townsend
# Misty Rush
# Tyler Rodgers
# Molly Turner
# Ashley Flores
# Julia Wolf
# Daniel Smith
# Stacey Williams
# Adam Lewis
# Jaclyn Moreno
# Robyn Ramirez
# Michelle Schneider
# Bobby Robbins
# Jared Lopez
# Dr. Julie Long
# Rebecca Beck
# John Murillo
# Bryan Hawkins
# Kathleen Jordan
# Brian Clay
# Angela Miller

# %%
# List now not a sting output but a list so it can be put into our DataFrame
print(Fake_Name_List)
# Out:
# ['Alexis Brown', 'Suzanne Myers', 'Brandon Johnson', 'Jamie Obrien', 'Mark Perez', 'Michael Warren', 'Carlos Dunn', 'Aaron Cohen', 'Jennifer Kelly', 'Madison Donovan', 'Jessica Alexander', 'Scott Gutierrez', 'John Hopkins', 'Jeremy Dawson', 'Thomas Davis', 'Jennifer Burns', 'Garrett Johnson', 'Audrey Bender', 'William Martin', 'Mary Sims', 'Jordan Garcia', 'Lauren Malone', 'Yvette Wilson', 'Theresa Price', 'William Johnson', 'Steven Fuller', 'Samuel Martinez', 'Amanda Smith', 'Anthony Olson', 'Taylor Hayes', 'Lisa Brandt', 'Alicia Ford', 'Howard Johnson', 'Bryan Munoz', 'Brandon Horn', 'Michelle Gregory', 'Christopher Pham', 'Joseph Larson', 'Julia Martin', 'Collin Cummings', 'Jerry Cordova', 'James Peterson', 'Rebecca Morales', 'Craig Smith', 'Anthony Herrera', 'Angela Williams', 'Cathy Roberts', 'Jason Martin', 'Andrew Parker', 'Richard Cardenas', 'Kyle Mckenzie', 'Dustin Nelson', 'Dr. Allen Wheeler', 'Kristen Harvey', 'Jose Hernandez', 'Anthony Wilson', 'Christopher Delgado', 'John Hall', 'Devin Davis', 'Ms. Emily Baird', 'Christopher Gibson', 'Corey West', 'Sarah Webb', 'Latoya Hodges', 'Jamie Kelly', 'Alexandra Shaw', 'Michael Lane', 'Luke Clarke', 'Stacy Howard', 'George Leonard', 'Michele Warner', 'Brittney Rogers', 'Lori Schmidt', 'Nicholas Klein', 'Jordan Braun', 'Paige Powell', 'Tracy Morris', 'David Watson', 'Ryan Walker', 'Michael Sanchez', 'Joshua Rodgers', 'Cheyenne Young', 'Joseph Jones', 'Todd Greene', 'Christine Mcfarland', 'Alex Wells', 'Rebecca Howard', 'Kimberly Guzman', 'Mary Sutton', 'Phyllis Carter', 'Kenneth Rivers', 'Dr. Tracy Conner', 'Kimberly Cook', 'Jermaine Smith', 'Victoria Beck', 'Ryan Beck', 'Brittany Richardson', 'Christian Ortiz', 'Marc Carson', 'William Taylor', 'Cynthia Russo', 'Kevin Drake', 'Rachel Bell', 'Chad White', 'Rhonda Obrien', 'Steven Sexton', 'Kayla Moore', 'Edward Ashley', 'Phillip Gomez', 'Jessica Rasmussen', 'Dale Scott', 'Thomas Crawford', 'Lisa Smith', 'Amber Gomez', 'William Lambert', 'Kathy Hoover', 'Elizabeth George', 'Erika Brewer', 'James Downs', 'Alicia Miller', 'Sarah Watts', 'Frank Adams', 'Matthew Lyons', 'Janice Valenzuela', 'Sydney Black', 'James Mitchell', 'Mrs. Brittany Simpson', 'Jennifer Bryant', 'Stephanie Freeman', 'Michael Edwards', 'Susan Wang MD', 'Denise Mueller', 'Bradley Campos', 'Stacy Swanson', 'Lauren Beck', 'Jose Castillo DVM', 'Audrey Hill', 'Donald Mitchell', 'Paige White', 'Michael Armstrong', 'Michael Taylor', 'Stephen Johnson', 'Taylor Weber', 'George Andrews', 'Christina Woods', 'Garrett Mason', 'Lisa Villarreal', 'Casey Jenkins', 'Lori Ferguson', 'Brooke Bryant', 'Joanna Anderson', 'Christopher Welch', 'Richard Knight', 'Travis Barnett', 'Philip Kirk', 'Lisa Bailey', 'Kristen Holmes', 'Lisa Robinson', 'Trevor Peterson', 'James Rodriguez', 'Kristin Valenzuela', 'Kathleen Roberts', 'Kerri Sanders', 'David Johnson', 'David Webb', 'Jill Leonard', 'Laura Mosley', 'Sheri Barnes', 'Sherry Matthews', 'Robert Smith', 'Charles Kelley', 'Jennifer Boyle', 'Dennis Bennett', 'Michael Smith', 'Anthony Gutierrez', 'Dakota Perez PhD', 'David Adams', 'Wendy Sanchez', 'Todd Preston', 'Chris Watson', 'Mark Burch', 'Adrian Smith', 'Christopher Lopez', 'Mrs. Ashley Vega DVM', 'Daniel Young', 'Lori Patel', 'Stephanie Fleming', 'Terry Rubio', 'Amy Moon', 'Katie Lawson', 'Michelle Liu', 'Alejandro Juarez', 'Marcus Casey', 'Alexander Martinez', 'Daniel Barrett', 'Amanda Wheeler', 'John Lee', 'Brian Mcguire', 'Victoria Wagner', 'Jeremy Miller', 'Allen Roberts', 'Teresa Strong', 'Damon Walker', 'Michael Shepard', 'Veronica Schneider', 'Chloe Bryant', 'Tina Willis', 'Christie Miller', 'Holly Miller', 'Matthew Herrera', 'Taylor Page', 'David Thompson', 'Joseph Jones', 'Michelle Krause', 'Phillip Conley', 'Lisa Price', 'Robert Vang', 'Jose Hubbard', 'Bianca Vincent', 'Susan Roth', 'Heather Jackson', 'Caroline Coleman', 'Nichole Hart', 'Adrienne Wiggins', 'Cassandra Wilson', 'Christine Sanchez', 'Amanda Hood', 'Lori Baker', 'Mr. Ronald Daniel', 'Kimberly Gonzalez', 'Prest ...

# %%
df_Names = pd.DataFrame(Fake_Name_List, columns=["Names"])
df_Names
# Out:
#                 Names
# 0        Alexis Brown
# 1       Suzanne Myers
# 2     Brandon Johnson
# 3        Jamie Obrien
# 4          Mark Perez
# ...               ...
# 1495  Madeline Harvey
# 1496   Julie Anderson
# 1497     Allison Gray
# 1498     Anthony Lane
# 1499     Ryan Hoffman
#
# [1500 rows x 1 columns]

# %%
# Generate a random normal distribution, centered on 4hrs (approx 60% of entire data), 3 std,/ 
# and size of 1500 data points as per ref[2].
Hrs_prep = np.random.normal(4, 3, 1500)
Hrs_prep
# Out:
# array([6.21205622, 2.14810865, 5.38879108, ..., 5.03632045, 4.84455262,
#        2.70719707])

# %%
df = pd.DataFrame(Hrs_prep, columns=["Hours_Preparation"])
df
# Out:
#       Hours_Preparation
# 0              6.212056
# 1              2.148109
# 2              5.388791
# 3              2.967429
# 4              6.938691
# ...                 ...
# 1495           3.907629
# 1496           7.983166
# 1497           5.036320
# 1498           4.844553
# 1499           2.707197
#
# [1500 rows x 1 columns]

# %%
df_Names.assign(Hours_Preparation= df)
df_Names= df_Names.assign(Hours_Preparation= df)
df_Names
# Out:
#                 Names  Hours_Preparation
# 0        Alexis Brown           6.212056
# 1       Suzanne Myers           2.148109
# 2     Brandon Johnson           5.388791
# 3        Jamie Obrien           2.967429
# 4          Mark Perez           6.938691
# ...               ...                ...
# 1495  Madeline Harvey           3.907629
# 1496   Julie Anderson           7.983166
# 1497     Allison Gray           5.036320
# 1498     Anthony Lane           4.844553
# 1499     Ryan Hoffman           2.707197
#
# [1500 rows x 2 columns]

# %%
# Visualise normal distribution, data used form Hrs_prep  random data, centred at 4
sns.histplot(data=Hrs_prep, kde=True)

# Generate a distplot with labels to visualise.
plt.title("Number of Hours Spent in Preparation")
plt.xlabel("Hours")
plt.ylabel("Number of Persons")
plt.show()

# %% [markdown]
# We can see here that the Hours spent in preparation for an interview follows a Normal Distribution curve.
#
# Normal Distributions can be used to represent random distribution for a wide range of real-world applications. Normal distributions have the following features:
#
# -symmetric bell shape [3]:
#
# -mean and median are equal; both located at the center of the distribution
#
# -Approx 68% of the data falls within 1 standard deviation of the mean
#
# -Approx 95% of the data falls within 2 standard deviations of the mean
#
# -Approx 99.7% of the data falls within 3 standard deviations of the mean

# %%
# At this point I realise that I can not have "negative study hours" and I possibly made a mistake when selecting the distribution.
# I will try a Log Noraml as this is seems to be a better fit to the data ref [2].

# Generate Log Normal Distribution 
Hrs_prep_1 = np.random.lognormal(1.5, .4, 1500)
Hrs_prep_1
# Out:
# array([ 3.8625124 ,  4.08426486,  4.07546444, ...,  4.20545012,
#         3.23472254, 11.98186015])

# %%
# Visualise normal distribution, data used form Hrs_prep  random data, centred at 4
sns.histplot(data=Hrs_prep_1, kde=True)

# Generate a distplot with labels to visualise.
plt.title("Number of Hours Spent in Preparation")
plt.xlabel("Hours")
plt.ylabel("Number of Persons")
plt.show()

# %% [markdown]
# Some descriptive figures- further analysis. Mean, Median, Std Dev, Min & Max Hrs.

# %%
# Mean Hrs study - this is extremely close to the 4hour or less study time on average/
# that people set aside for interview preparation. Therefore the Log Normal Distribution is acurrate fit
np.mean(Hrs_prep_1)
# Out:
# 4.878369844021902

# %%
# Median Hrs study
np.median(Hrs_prep_1)
# Out:
# 4.447813092234217

# %%
# Standard Dev
np.std(Hrs_prep_1)
# Out:
# 2.130569183702808

# %%
# Average Min Hrs study 
np.min(Hrs_prep_1)
# Out:
# 1.1931130288086225

# %%
# Average Max Hrs study
np.max(Hrs_prep_1)
# Out:
# 17.706476725374802

# %% [markdown]
# ***

# %% [markdown]
# <br>
#
# ## Level of Qualifications

# %% [markdown]
# The internet has made it very easy for people to search out and apply to many job opportunities. But sending out more applications doesn’t increase your chances of getting hired. A vast number of employers have told Workopolis Work that as many as 75% of job applicants for a given role aren’t actually qualified to do it! Furthermore, they state that an even smaller fraction than that are selected for an interview [5].
#
# “98% of job seekers are eliminated at the initial resume screening and only the Top 2% of candidates make it to the interview”, says Robert Meier, President of Job Market Experts. “Fixing the employment market requires helping job seekers become “Top 2% Candidates” who can meet employer’s rigorous requirements and easily hit the “bulls-eye” of employer needs to ensure they don’t make bad hires” continued Meier [5].

# %%
# Create  a list of Qualifications 
Qualifications = ["None", "Under_Qualified", "Somewhat_Qualified", "Qualified", "Over_Qualified"]
Qualifications
# Out:
# ['None',
#  'Under_Qualified',
#  'Somewhat_Qualified',
#  'Qualified',
#  'Over_Qualified']

# %%
# 75% of choices will be not have the required qualifications 
np.random.choice(Qualifications, 1501, p=[0.05, 0.25, 0.45, 0.2, 0.05])
# Out:
# array(['Under_Qualified', 'Somewhat_Qualified', 'Qualified', ...,
#        'Under_Qualified', 'Somewhat_Qualified', 'Somewhat_Qualified'],
#       dtype='<U18')

# %%
Qual= np.random.choice(Qualifications, 1500, p=[0.05, 0.25, 0.45, 0.2, 0.05])
Qual
# Out:
# array(['Qualified', 'Somewhat_Qualified', 'Somewhat_Qualified', ...,
#        'Qualified', 'Somewhat_Qualified', 'Qualified'], dtype='<U18')

# %%
# Create a DataFrame to view the Qualifications output
df_1 = pd.DataFrame(Qual, columns=["Qualifications"])
df_1
# Out:
#           Qualifications
# 0              Qualified
# 1     Somewhat_Qualified
# 2     Somewhat_Qualified
# 3     Somewhat_Qualified
# 4        Under_Qualified
# ...                  ...
# 1495  Somewhat_Qualified
# 1496     Under_Qualified
# 1497           Qualified
# 1498  Somewhat_Qualified
# 1499           Qualified
#
# [1500 rows x 1 columns]

# %%
# Add Second Variable to our Data Frame. This is probably the simplist way to add the new column.
df_Names.assign(Qualifications= df_1)
df_Names = df_Names.assign(Qualifications= df_1)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications
# 0        Alexis Brown           6.212056           Qualified
# 1       Suzanne Myers           2.148109  Somewhat_Qualified
# 2     Brandon Johnson           5.388791  Somewhat_Qualified
# 3        Jamie Obrien           2.967429  Somewhat_Qualified
# 4          Mark Perez           6.938691     Under_Qualified
# ...               ...                ...                 ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified
# 1496   Julie Anderson           7.983166     Under_Qualified
# 1497     Allison Gray           5.036320           Qualified
# 1498     Anthony Lane           4.844553  Somewhat_Qualified
# 1499     Ryan Hoffman           2.707197           Qualified
#
# [1500 rows x 3 columns]

# %%
# Create a countplot to illustrate the data better 
sns.countplot(x="Qualifications", data=df_1, palette="Set3",)
plt.show()

# %%
# Controlling the graph so that it flows in descending manner [6]
sns.countplot(x="Qualifications", data=df_1, palette="Set3", order = df_1["Qualifications"].value_counts().index)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Level of Relevant Job Experience

# %% [markdown]
# According to Zety.com, (a leading career site with a community of over 40 million readers a year) recruiters look for the following [7]:
#
# ![What%20recruiters%20look%20for.png](attachment:What%20recruiters%20look%20for.png)
#
#
#
# Job experience ranks top of the list when considering applicants. Furthermore, a survey conducted by the Universities and Colleges Admissions Service(UCAS) showed two thirds of employers look for graduates with relevant work experience because it helps them prepare for work and develop general business awareness. Importantly, one third of employers felt that applicants did not have a satisfactory level of knowledge about their chosen career or job [8].
#
# Dokko, Wilk and Rothbard (2009) stated that u on examining the employers want for relevant job experience for potential employees that "we find that prior occupational experience has a positive effect on performance via knowledge and skill"[9].
#
# From these 3 sources a good estimation I would consider for applicants to have desired levels of experience would be 66% or two thirds of the total applicants applying for the job. That is to say that one third of applicants do not meet the ideal levels of relevant job experience for the said position.

# %%
# Create a binary list of experience - either yes or no
Experience = ["Yes", "No"]
np.random.choice (Experience, 1500, p=[0.67, 0.33])
Experience = np.random.choice (Experience, 1500, p=[0.67, 0.33])

Experience
# Out:
# array(['No', 'Yes', 'No', ..., 'No', 'Yes', 'No'], dtype='<U3')

# %%
# count to make sure 1500 yes and No answers are there.
from collections import Counter
Counter(Experience)
# Out:
# Counter({'No': 503, 'Yes': 997})

# %%
# Create a DataFrame for Job_Experience
df_2 = pd.DataFrame(Experience, columns=["Job_Experience"])
df_2
# Out:
#      Job_Experience
# 0                No
# 1               Yes
# 2                No
# 3                No
# 4               Yes
# ...             ...
# 1495            Yes
# 1496            Yes
# 1497             No
# 1498            Yes
# 1499             No
#
# [1500 rows x 1 columns]

# %%
# Add the third Variable to our Data Frame. 
df_Names.assign(Job_Experience= df_2)
df_Names = df_Names.assign(Job_Experience= df_2)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
# [1500 rows x 4 columns]

# %%
labels = "Yes", "No"
sizes = [997, 503]
explode = (0, 0.1)

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=90)
ax1.axis("equal")
plt.title("Job_Experience")
plt.show()

# %% [markdown]
# ## First Impressions
#
# The old saying, "First impressions are everything" rings true in many cases. Sadly, many interviewers will decide to not hire a candidate within the first 30 seconds to 3 minutes, based on a poor first impression; so don't hurt your chances by arriving at an interview and making a poor first impression. Certain interviewers do put far too much emphasis on first impressions, this is the "human factor" which is hard to factor into the success rate, however this is the reality of the hiring process [10].

# %% [markdown]
# McIntosh (2014), in his book titled  "Job Interview Success for Introverts" identified the following key variables as having a major impact on first impressions, and subsequent to this a dramatic effect on the chances of success for the applicant. In order to consider first impressions eye contact, the handshake, the smile and the posture of applicants will be simulated [10]:
#
# - Eye Contact. Making steady eye contact is essential at interviews, as it tells the interviewer(s) that you are trustworthy, engaged, interested, enthusiastic, and aren't hiding something. Your eye contact is part of your communications; in other words, you can speak with your eyes. Eyes wide open can indicate excitement and happiness, while slightly closed eyes can indicate disapproval and even anger
#
#
# - The Handshake. This is quite topical now and certainly given the unprecedented situation with COVID,now we see  the elements concerning first impression once centerted on the handshake are now negated. However for the sake of this assignment we will continue as normal. The handshake is just as important as eye contact, its a form of communication. The general rule on handshakes is to deliver one that is firm yet gentle. A hand shake that is too firm can be seen as aggressive, while a handshake that is to gentle can be seen as weak or cunning.
#
#
# - The Smile. A smile tells the interviewers that you're happy to be there. Most people are naturally drawn more to people who smile than those who don't. But don't force a smile that comes across as fake.
#
#
# - Your Posture. How you sit is also important. Interviewers will observe your posture and body language, so be cognizant of how straight you're sitting and if you are fidgeting with your fingers or hands or even tapping your feet
#
#
# - Small Talk. Your ability to engage in small talk speaks to your verbal communication skills, ability to reason, and how well you think quickly on your feet. If this is important to the interviewer(s), they'll be paying close attention to how well you can interact quickly and naturally

# %%
# In order to simulate if the various applicants have made a positive impression or not I will first consider each variable 
# 1)Eye contact, 2) The Handshake, 3) The Smile, 4) The Posture, and 5) Small Talk.
# The sum totality of performance among persons will be considered if they made a good impression or not.

# %% [markdown]
# ### Eye Contact

# %% [markdown]
# Zuckerman et al. (1981) suggested that liars might fidget more than truth tellers, and they may also sound more unpleasant. They also suggested that guilt and anxiety could become apparent in liars' distancing of themselves from their deceptive communications. lying can be cognitively more demanding than truth telling. The lack of eye contact can be seen as a negative. For this Assignment we will assume 90% of applicants maintain good eye contact.

# %%
# Call up DataFrame
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
# [1500 rows x 4 columns]

# %%
# Create eye contact list
Eye_Contact = ["Good_Eye_Contact", "Bad_Eye_Contact"]

# %%
# Create eye contact variable that contains a random choice 90% "Good" and 10% "Bad" Eye contact
Eye_Contact= np.random.choice(Eye_Contact, 1500, p=[0.9, 0.1])
Eye_Contact
# Out:
# array(['Good_Eye_Contact', 'Good_Eye_Contact', 'Good_Eye_Contact', ...,
#        'Good_Eye_Contact', 'Good_Eye_Contact', 'Good_Eye_Contact'],
#       dtype='<U16')

# %%
# Check 90% / 10% split 
Counter(Eye_Contact)
# Out:
# Counter({'Good_Eye_Contact': 1336, 'Bad_Eye_Contact': 164})

# %%
# Create DataFrame for eye contact
df_0a = pd.DataFrame(Eye_Contact, columns=["Eye_Contact_Rating"])
df_0a
# Out:
#      Eye_Contact_Rating
# 0      Good_Eye_Contact
# 1      Good_Eye_Contact
# 2      Good_Eye_Contact
# 3      Good_Eye_Contact
# 4      Good_Eye_Contact
# ...                 ...
# 1495   Good_Eye_Contact
# 1496   Good_Eye_Contact
# 1497   Good_Eye_Contact
# 1498   Good_Eye_Contact
# 1499   Good_Eye_Contact
#
# [1500 rows x 1 columns]

# %%
# Add Eye_Contact to our Data Frame
df_Names.assign(Eye_Contact_Rating= df_0a)
df_Names = df_Names.assign(Eye_Contact_Rating= df_0a)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience  \
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
#      Eye_Contact_Rating
# 0      Good_Eye_Contact
# 1      Good_Eye_Contact
# 2      Good_Eye_Contact
# 3      Good_Eye_Contact
# 4      Good_Eye_Contact
# ...                 ...
# 1495   Good_Eye_Contact
# 1496   Good_Eye_Contact
# 1497   Good_Eye_Contact
# 1498   Good_Eye_Contact
# 1499   Good_Eye_Contact
#
# [1500 rows x 5 columns]

# %% [markdown]
# ### The Handshake
#
# The handshake remains one of the sole physical contact among professionals and an important part of everyday business dealings. A good shake is expected and for the most part should go unnoticed, but a bad one could cost you. In fact, in this tight economy, even with the most basic salutations one can gain an advantage over other prospects who may be applying for the same job position. Why is a handshake so important? Because in less than five seconds, a prospective employer, client or business associate can learn a lot about you - whether you’re trustworthy, confident and competent, and whether you follow through![12].
#
# For the purpose of the assignment I will assume that 85% of applicants demonstrate a "good handshake" while 15% demonstrate a "poor handshake"

# %%
# Create a handshake list containing good & bad handshakes 
Handshake = ["Good_Handshake", "Bad_Handshake"]

# Create handshake variable that contains a random choice 85% "Good" and 15% "Bad" Handshakes
Handshake= np.random.choice(Handshake, 1500, p=[0.85, 0.15])
Handshake
# Out:
# array(['Good_Handshake', 'Good_Handshake', 'Good_Handshake', ...,
#        'Bad_Handshake', 'Good_Handshake', 'Good_Handshake'], dtype='<U14')

# %%
# Check 85% / 15% split 
Counter(Handshake)
# Out:
# Counter({'Good_Handshake': 1280, 'Bad_Handshake': 220})

# %%
# Create DataFrame for eye contact
df_0b = pd.DataFrame(Handshake, columns=["Handshake_Rating"])
df_0b
# Out:
#      Handshake_Rating
# 0      Good_Handshake
# 1      Good_Handshake
# 2      Good_Handshake
# 3      Good_Handshake
# 4      Good_Handshake
# ...               ...
# 1495   Good_Handshake
# 1496   Good_Handshake
# 1497    Bad_Handshake
# 1498   Good_Handshake
# 1499   Good_Handshake
#
# [1500 rows x 1 columns]

# %%
# Add Handshake Variable to our Data Frame
df_Names.assign(Handshake_Rating= df_0b)
df_Names = df_Names.assign(Handshake_Rating= df_0b)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience  \
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
#      Eye_Contact_Rating Handshake_Rating
# 0      Good_Eye_Contact   Good_Handshake
# 1      Good_Eye_Contact   Good_Handshake
# 2      Good_Eye_Contact   Good_Handshake
# 3      Good_Eye_Contact   Good_Handshake
# 4      Good_Eye_Contact   Good_Handshake
# ...                 ...              ...
# 1495   Good_Eye_Contact   Good_Handshake
# 1496   Good_Eye_Contact   Good_Handshake
# 1497   Good_Eye_Contact    Bad_Handshake
# 1498   Good_Eye_Contact   Good_Handshake
# 1499   Good_Eye_Contact   Good_Handshake
#
# [1500 rows x 6 columns]

# %% [markdown]
# ### The Smile
#
# Winkielman and Cacioppo (2001) conducted a study  which showed that smiling faces puts the mind at ease. A smiling face is a more trusthworth face and projects out a more socially acceptable expression. In short it is hard to be angry or mad at a smiling face when it is genuine. In the context of a job interview a  positive smile can go a long way towards "getting the rub of the green" and may sway interviewers opinion of the applicant in very subtle ways. Not everyone can act natural and seem at ease, especially during pressure situations and test conditions such as a job interview [14].
#
# According to a survey from  Small Business Trends 29% of respondents said that a job interview made them nervous, when ranking the top things in life which was a source of anxiety. This was the second ranked source of anxiety for most people [14].
#
# Therefore bearing this in mind and for the purpose of the assignment a rate of 70% Smile and 30% no Smile will be used. It may be noted as also that a person may be anxious and still smile.
#
# ![What%20makes%20you%20most%20nervous.png](attachment:What%20makes%20you%20most%20nervous.png)

# %%
# Create a smile list containing good & bad smiles 
Smile = ["Good_Smile", "Bad_Smile"]

# Create smile variable that contains a random choice 70% "Good" and 30% "Bad" smiles
Smile= np.random.choice(Smile, 1500, p=[0.70, 0.30])
Smile
# Out:
# array(['Good_Smile', 'Good_Smile', 'Bad_Smile', ..., 'Bad_Smile',
#        'Good_Smile', 'Good_Smile'], dtype='<U10')

# %%
# Check 70% / 30% split 
Counter(Smile)
# Out:
# Counter({'Good_Smile': 1079, 'Bad_Smile': 421})

# %%
# Create DataFrame for smile
df_0c = pd.DataFrame(Smile, columns=["Smile_Rating"])
df_0c
# Out:
#      Smile_Rating
# 0      Good_Smile
# 1      Good_Smile
# 2       Bad_Smile
# 3       Bad_Smile
# 4      Good_Smile
# ...           ...
# 1495   Good_Smile
# 1496   Good_Smile
# 1497    Bad_Smile
# 1498   Good_Smile
# 1499   Good_Smile
#
# [1500 rows x 1 columns]

# %%
# Add Smile Variable to our Data Frame
df_Names.assign(Smile_Rating= df_0c)
df_Names = df_Names.assign(Smile_Rating= df_0c)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience  \
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
#      Eye_Contact_Rating Handshake_Rating Smile_Rating
# 0      Good_Eye_Contact   Good_Handshake   Good_Smile
# 1      Good_Eye_Contact   Good_Handshake   Good_Smile
# 2      Good_Eye_Contact   Good_Handshake    Bad_Smile
# 3      Good_Eye_Contact   Good_Handshake    Bad_Smile
# 4      Good_Eye_Contact   Good_Handshake   Good_Smile
# ...                 ...              ...          ...
# 1495   Good_Eye_Contact   Good_Handshake   Good_Smile
# 1496   Good_Eye_Contact   Good_Handshake   Good_Smile
# 1497   Good_Eye_Contact    Bad_Handshake    Bad_Smile
# 1498   Good_Eye_Contact   Good_Handshake   Good_Smile
# 1499   Good_Eye_Contact   Good_Handshake   Good_Smile
#
# [1500 rows x 7 columns]

# %% [markdown]
# ### Posture
# In social psychology, numerous studies have indicated that the initial judgments perceivers make of the people with whom they interact can have an influence on the course and outcomes of social interactions.
#
# So, getting one’s body to speak the right language in the first time is very crucial, because, as it is often said,
# “one may not get another chance to make a good first impression.” This is crucial because,
# according to Bright (2009); and Reeves (2006), the candidate has just a mere 10 seconds to make a good impression, and teh posture of the individual plays an integral part of this.
#
# Career Playbook,(2011) presents an assumption in which all candidates who appear for interviews are qualified to various degrees. That is, they all possess the Functional Requirements for the job. The best-fit candidate is the
# one who gets the job. This best-fit is suggested to consist of:
#
#
#  - 50% good chemistry (can you fit into the organization?)
#
#
# - 30% competency (can you do the job?), and
#
#
# - 20% willingness and enthusiasm (will you do the job?)
#
#
# These suggest that “good chemistry” is what the candidate should **project from his or her body
# language** [18].
#
# For the purpose of this assignment a rate of 95% good posture and 5% bad posture will be used.

# %%
# Create a posture list containing good & bad posture 
Posture = ["Good_Posture", "Bad_Posture"]

# Create smile variable that contains a random choice 70% "Good" and 30% "Bad" smiles
Posture= np.random.choice(Posture, 1500, p=[0.90, 0.10])
Posture
# Out:
# array(['Good_Posture', 'Bad_Posture', 'Good_Posture', ..., 'Good_Posture',
#        'Bad_Posture', 'Good_Posture'], dtype='<U12')

# %%
# Check 90% / 10% split 
Counter(Posture)
# Out:
# Counter({'Good_Posture': 1341, 'Bad_Posture': 159})

# %%
# Create DataFrame for smile
df_0d = pd.DataFrame(Posture, columns=["Posture_Rating"])
df_0d
# Out:
#      Posture_Rating
# 0      Good_Posture
# 1       Bad_Posture
# 2      Good_Posture
# 3      Good_Posture
# 4      Good_Posture
# ...             ...
# 1495   Good_Posture
# 1496   Good_Posture
# 1497   Good_Posture
# 1498    Bad_Posture
# 1499   Good_Posture
#
# [1500 rows x 1 columns]

# %%
# Add Posture Variable to our Data Frame
df_Names.assign(Posture_Rating= df_0d)
df_Names = df_Names.assign(Posture_Rating= df_0d)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience  \
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
#      Eye_Contact_Rating Handshake_Rating Smile_Rating Posture_Rating
# 0      Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# 1      Good_Eye_Contact   Good_Handshake   Good_Smile    Bad_Posture
# 2      Good_Eye_Contact   Good_Handshake    Bad_Smile   Good_Posture
# 3      Good_Eye_Contact   Good_Handshake    Bad_Smile   Good_Posture
# 4      Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# ...                 ...              ...          ...            ...
# 1495   Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# 1496   Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# 1497   Good_Eye_Contact    Bad_Handshake    Bad_Smile   Good_Posture
# 1498   Good_Eye_Contact   Good_Handshake   Good_Smile    Bad_Posture
# 1499   Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
#
# [1500 rows x 8 columns]

# %% [markdown]
# ### Small Talk
#
# Your ability to engage in small talk speaks to your verbal communication skills, ability to reason, and how well you think quickly on your feet. If this is important to the interviewer(s), they'll be paying close attention to how well you can interact quickly and naturally.
#
#
# According to Krishnan et al. (2019) they state that communication skills for job interviews play an important role since it turns out to be of the major criteria of employability ever since the 20th century. This is apparent as many university graduates are unable to secure a job within 3-6 months after graduation due to poor communication skills. The inaccurate vocabulary (clarity), incomplete sentences (conciseness), unable to provide detailed answers (completeness), and error in grammar in the utterances and sentences (correctness) are found in the communication skills by job applicants [19].

# %%
# Create a Small Talk list containing good & small talk 
Talk = ["Good_Talk", "Bad_Talk"]

# Create Talk variable that contains a random choice 80% "Good" and 20% "Bad" Talk
Talk= np.random.choice(Talk, 1500, p=[0.80, 0.20])
Talk
# Out:
# array(['Good_Talk', 'Good_Talk', 'Good_Talk', ..., 'Good_Talk',
#        'Good_Talk', 'Good_Talk'], dtype='<U9')

# %%
# Check 80% / 20% split 
Counter(Talk)
# Out:
# Counter({'Good_Talk': 1219, 'Bad_Talk': 281})

# %%
# Create DataFrame for Talk
df_0e = pd.DataFrame(Talk, columns=["Talk_Rating"])
df_0e
# Out:
#      Talk_Rating
# 0      Good_Talk
# 1      Good_Talk
# 2      Good_Talk
# 3      Good_Talk
# 4      Good_Talk
# ...          ...
# 1495   Good_Talk
# 1496   Good_Talk
# 1497   Good_Talk
# 1498   Good_Talk
# 1499   Good_Talk
#
# [1500 rows x 1 columns]

# %%
# Add Posture Variable to our Data Frame
df_Names.assign(Talk_Rating= df_0e)
df_Names = df_Names.assign(Talk_Rating= df_0e)
df_Names
# Out:
#                 Names  Hours_Preparation      Qualifications Job_Experience  \
# 0        Alexis Brown           6.212056           Qualified             No
# 1       Suzanne Myers           2.148109  Somewhat_Qualified            Yes
# 2     Brandon Johnson           5.388791  Somewhat_Qualified             No
# 3        Jamie Obrien           2.967429  Somewhat_Qualified             No
# 4          Mark Perez           6.938691     Under_Qualified            Yes
# ...               ...                ...                 ...            ...
# 1495  Madeline Harvey           3.907629  Somewhat_Qualified            Yes
# 1496   Julie Anderson           7.983166     Under_Qualified            Yes
# 1497     Allison Gray           5.036320           Qualified             No
# 1498     Anthony Lane           4.844553  Somewhat_Qualified            Yes
# 1499     Ryan Hoffman           2.707197           Qualified             No
#
#      Eye_Contact_Rating Handshake_Rating Smile_Rating Posture_Rating  \
# 0      Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# 1      Good_Eye_Contact   Good_Handshake   Good_Smile    Bad_Posture
# 2      Good_Eye_Contact   Good_Handshake    Bad_Smile   Good_Posture
# 3      Good_Eye_Contact   Good_Handshake    Bad_Smile   Good_Posture
# 4      Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# ...                 ...              ...          ...            ...
# 1495   Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# 1496   Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
# 1497   Good_Eye_Contact    Bad_Handshake    Bad_Smile   Good_Posture
# 1498   Good_Eye_Contact   Good_Handshake   Good_Smile    Bad_Posture
# 1499   Good_Eye_Contact   Good_Handshake   Good_Smile   Good_Posture
#
#      Talk_Rating
# 0      Good_Talk
# 1      Good_Talk
# 2      Good_Talk
# 3      Good_Talk
# 4      Good_Talk
# ...          ...
# 1495   Good_Talk
# 1496   Good_Talk
# 1497   Good_Talk
# 1498   Good_Talk
# 1499   Good_Talk
#
# [1500 rows x 9 columns]

# %% [markdown]
# # References
#
# [1] I-Python built-in Magic Commands https://ipython.readthedocs.io/en/stable/interactive/magics.html
#
# [2] Global Career Hub. ttps://mycareer.aicpa-cima.com/article/how-to-prepare-for-a-job-interview/
#
# [3] Investopedia- Empirical Rule. https://www.investopedia.com/terms/e/empirical-rule.asp#:~:text=The%20Empirical%20Rule%20states%20that,standard%20deviations%20from%20the%20mean.
#
# [4] D. Aswath, Strategic Risk Taking: A Framework for Risk Management, Pearson Prentice Hall, 2008.
#
# [5] Workopolis-Why only 2% of applicants actually get interviews.  https://careers.workopolis.com/advice/only-2-of-applicants-actually-get-interviews-heres-how-to-be-one-of-them/
#
# [6] Python: Add column to dataframe in Pandas ( based on other column or list or default value) https://thispointer.com/python-pandas-how-to-add-new-columns-in-a-dataframe-using-or-dataframe-assign/
#
# [7] Zesty- 2020 HR Statistics: Job Search, Hiring, Recruiting & Interviews. https://zety.com/blog/hr-statistics
#
# [8] UCAS-IS WORK EXPERIENCE IMPORTANT?. https://www.ucas.com/connect/blogs/work-experience-important#:~:text=A%20recent%20survey%20showed%20two,and%20develop%20general%20business%20awareness.&text=To%20gain%20a%20better%20understanding,work%20shadowing%20with%20an%20employer.
#
# [9] Dokko, G., Wilk, S.L. and Rothbard, N.P., 2009. Unpacking prior experience: How career history affects job performance. Organization Science, 20(1), pp.51-68.
#
# [10] McIntosh, B. (2014) Job Interview Success for Introverts. Birmingham, UK: Impackt Publishing.
#
# [11] Zuckerman, M., DePaulo, B.M. and Rosenthal, R., 1981. Verbal and nonverbal communication of deception. In Advances in experimental social psychology (Vol. 14, pp. 1-59). Academic Press.
#
# [12] Mastering The Handshake: 5 Things You Need To Know. https://www.huffpost.com/entry/mastering-the-handshake-5-things_n_917310?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAADCj8ugWEy8qGmHfTzqqjYm5-ntCBsTWSXYtT5zZmDjGYtYUlxXoryf-t64DMcJBEsya4yhtMvzaME3Wzy4OD9o4LVSj1z69EP8NQBmoeemZA8wjddBpb3QM3lM6DmN22gp0cMzto3cPIY6dDNfeWvWV-fkRXQJXLoGCuo1BZBcT
# [13] Winkielman, P. and Cacioppo, J.T., 2001. Mind at ease puts a smile on the face: psychophysiological evidence that processing facilitation elicits positive affect. Journal of personality and social psychology, 81(6), p.989.
#
# [14] Winkielman, P. and Cacioppo, J.T., 2001. Mind at ease puts a smile on the face: psychophysiological evidence that processing facilitation elicits positive affect. Journal of personality and social psychology, 81(6), p.989.
#
# [15] Small Business Trends. https://smallbiztrends.com/2020/05/job-interview-anxiety-survey.html
#
# [16] Reeves, S., (2006). Is Your Body Betraying you in Job Interviews?
# Retrieved from http://www.forbes.com/2006/02/15/employment-careers-interviewscx_sr_0216bizbasics.html on Nov/18/2011.
#
# [17] Bright, J., (2009). Get What you Want at an Interview. Retrieved from
# http://content.mycareer.com.au/advice-research/interview/how-to-sell-yourself-atinterviews.aspx?printerfriendly=True on Dec/2/2011.
#
# [18] CareerPlaybook, (2011). Job Interview Preparation, Techniques & Tips. Retrieved from http://www.careerplybook.com/guide/prepare_for_job_interview.asp
#
# [19] Krishnan, I.A., Ching, H.S., Ramalingam, S. and Maruthai, E., 2019. An Investigation of Communication Skills Required by Employers from the Fresh Graduates. Pertanika Journal of Social Sciences & Humanities, 27(2).
